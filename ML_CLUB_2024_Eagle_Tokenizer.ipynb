# %% [markdown]
# <a href="https://colab.research.google.com/github/msamwelmollel/ML-CLUB-2024-Eagle-Labs/blob/main/ML_CLUB_2024_Eagle_Tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Example text with Python code
text = """
PEP 8: Style Guide for Python Code.

This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:
This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:

1. Use 4 spaces per indentation level.

2. Limit all lines to a maximum of 79 characters.

3. Imports should usually be on separate lines:

import os
import sys

4. Surround top-level function and class definitions with two blank lines.

def example_function():
    '''This is a docstring.'''
    return None

class ExampleClass:
    '''This is a class docstring.'''

    def __init__(self, value):
        self.value = value

    def get_value(self):
        return self.value

5. Use inline comments sparingly:

x = x + 1  # Compensate for border

6. Use docstrings for all public modules, functions, classes, and methods.

Remember, code is read much more often than it is written. Clarity and readability are paramount!
"""

# %%
# print(text)

# %%
# Tokenizer initialization (using a BERT tokenizer as an example)
try:
    tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
    model = AutoModel.from_pretrained("bert-base-uncased")
except Exception as e:
    print(f"Error loading tokenizer or model: {e}")
    exit(1)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
# Helper function for tokenizing text
def tokenize(text):
    return tokenizer.tokenize(text)

# %%
# Helper function to convert token list to string
def tokens_to_string(tokens):
    return tokenizer.convert_tokens_to_string(tokens)

# %%
# Helper function to generate embeddings
def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# %%
# Fixed token without overlap
def fixed_token_without_overlap(text, chunk_size):
    tokens = tokenize(text)
    return [tokens[i:i + chunk_size] for i in range(0, len(tokens), chunk_size)]

# %%
# Fixed token with overlap
def fixed_token_with_overlap(text, chunk_size, overlap):
    tokens = tokenize(text)
    return [tokens[i:i + chunk_size] for i in range(0, len(tokens), chunk_size - overlap)]

# %%
# Recursive with overlap
def recursive_with_overlap(text, chunk_size, overlap):
    paragraphs = text.split('\n\n')
    chunks = []
    for paragraph in paragraphs:
        sentences = re.split(r'(?<=[.!?]) +', paragraph)
        paragraph_tokens = []
        for sentence in sentences:
            sentence_tokens = tokenize(sentence)
            paragraph_tokens.extend(sentence_tokens)
            if len(paragraph_tokens) >= chunk_size:
                chunks.append(paragraph_tokens[:chunk_size])
                paragraph_tokens = paragraph_tokens[chunk_size - overlap:]
        if paragraph_tokens:
            chunks.append(paragraph_tokens)
    return chunks

# %%
# Recursive Python splitter with overlap
def recursive_python_splitter_with_overlap(text, chunk_size, overlap):
    code_splits = re.split(r'(\nclass|\ndef|\n)', text)
    chunks = []
    current_chunk = []
    for part in code_splits:
        tokens = tokenize(part)
        current_chunk.extend(tokens)
        if len(current_chunk) >= chunk_size:
            chunks.append(current_chunk[:chunk_size])
            current_chunk = current_chunk[chunk_size - overlap:]
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# %%
# Semantic chunking
def semantic_chunking(text, similarity_threshold=0.8):
    sentences = re.split(r'(?<=[.!?]) +', text)
    sentence_groups = [' '.join(sentences[i:i+3]) for i in range(0, len(sentences), 3)]

    embeddings = [get_embedding(group) for group in sentence_groups]

    chunks = []
    current_chunk = []

    for i, group in enumerate(sentence_groups):
        if not current_chunk:
            current_chunk.append(group)
        else:
            similarity = cosine_similarity([embeddings[i]], [np.mean(embeddings[max(0, i-3):i], axis=0)])[0][0]
            if similarity >= similarity_threshold:
                current_chunk.append(group)
            else:
                chunks.append(' '.join(current_chunk))
                current_chunk = [group]

    if current_chunk:
        chunks.append(' '.join(current_chunk))

    return chunks

# %%
# Example usage
chunk_size = 50
overlap = 20

# %%
print("Fixed Token without Overlap:")
print("Number of chunks", len(fixed_token_without_overlap(text, chunk_size)))
print(fixed_token_without_overlap(text, chunk_size))

print("\nFixed Token with Overlap:")
print("Number of chunks", len(fixed_token_with_overlap(text, chunk_size, overlap)))
print(fixed_token_with_overlap(text, chunk_size, overlap))

print("\nRecursive with Overlap:")
print("Number of chunks", len(recursive_with_overlap(text, chunk_size, overlap)))
print(recursive_with_overlap(text, chunk_size, overlap))

print("\nRecursive Python Splitter with Overlap:")
print("Number of chunks", len(recursive_python_splitter_with_overlap(text, chunk_size, overlap)))
print(recursive_python_splitter_with_overlap(text, chunk_size, overlap))
# Out:
# Fixed Token without Overlap:
# Number of chunks 13
# [['pep', '8', ':', 'style', 'guide', 'for', 'python', 'code', '.', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its'], ['goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':'], ['this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency'], ['across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':', '1', '.', 'use', '4', 'spaces', 'per', 'ind', '##entation', 'level'], ['.', '2', '.', 'limit', 'all', 'lines', 'to', 'a', 'maximum', 'of', '79', 'characters', '.', '3', '.', 'imports', 'should', 'usually', 'be', 'on'], ['separate', 'lines', ':', 'import', 'os', 'import', 'sy', '##s', '4', '.', 'surround', 'top', '-', 'level', 'function', 'and', 'class', 'definitions', 'with', 'two'], ['blank', 'lines', '.', 'def', 'example', '_', 'function', '(', ')', ':', "'", "'", "'", 'this', 'is', 'a', 'doc', '##st', '##ring', '.'], ["'", "'", "'", 'return', 'none', 'class', 'example', '##class', ':', "'", "'", "'", 'this', 'is', 'a', 'class', 'doc', '##st', '##ring', '.'], ["'", "'", "'", 'def', '_', '_', 'in', '##it', '_', '_', '(', 'self', ',', 'value', ')', ':', 'self', '.', 'value', '='], ['value', 'def', 'get', '_', 'value', '(', 'self', ')', ':', 'return', 'self', '.', 'value', '5', '.', 'use', 'inline', 'comments', 'spa', '##ring'], ['##ly', ':', 'x', '=', 'x', '+', '1', '#', 'compensate', 'for', 'border', '6', '.', 'use', 'doc', '##st', '##ring', '##s', 'for', 'all'], ['public', 'modules', ',', 'functions', ',', 'classes', ',', 'and', 'methods', '.', 'remember', ',', 'code', 'is', 'read', 'much', 'more', 'often', 'than', 'it'], ['is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!']]
#
# Fixed Token with Overlap:
# Number of chunks 25
# [['pep', '8', ':', 'style', 'guide', 'for', 'python', 'code', '.', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its'], ['pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across'], ['goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':'], ['the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.'], ['this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency'], ['its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points'], ['across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':', '1', '.', 'use', '4', 'spaces', 'per', 'ind', '##entation', 'level'], [':', '1', '.', 'use', '4', 'spaces', 'per', 'ind', '##entation', 'level', '.', '2', '.', 'limit', 'all', 'lines', 'to', 'a', 'maximum', 'of'], ['.', '2', '.', 'limit', 'all', 'lines', 'to', 'a', 'maximum', 'of', '79', 'characters', '.', '3', '.', 'imports', 'should', 'usually', 'be', 'on'], ['79', 'characters', '.', '3', '.', 'imports', 'should', 'usually', 'be', 'on', 'separate', 'lines', ':', 'import', 'os', 'import', 'sy', '##s', '4', '.'], ['separate', 'lines', ':', 'import', 'os', 'import', 'sy', '##s', '4', '.', 'surround', 'top', '-', 'level', 'function', 'and', 'class', 'definitions', 'with', 'two'], ['surround', 'top', '-', 'level', 'function', 'and', 'class', 'definitions', 'with', 'two', 'blank', 'lines', '.', 'def', 'example', '_', 'function', '(', ')', ':'], ['blank', 'lines', '.', 'def', 'example', '_', 'function', '(', ')', ':', "'", "'", "'", 'this', 'is', 'a', 'doc', '##st', '##ring', '.'], ["'", "'", "'", 'this', 'is', 'a', 'doc', '##st', '##ring', '.', "'", "'", "'", 'return', 'none', 'class', 'example', '##class', ':', "'"], ["'", "'", "'", 'return', 'none', 'class', 'example', '##class', ':', "'", "'", "'", 'this', 'is', 'a', 'class', 'doc', '##st', '##ring', '.'], ["'", "'", 'this', 'is', 'a', 'class', 'doc', '##st', '##ring', '.', "'", "'", "'", 'def', '_', '_', 'in', '##it', '_', '_'], ["'", "'", "'", 'def', '_', '_', 'in', '##it', '_', '_', '(', 'self', ',', 'value', ')', ':', 'self', '.', 'value', '='], ['(', 'self', ',', 'value', ')', ':', 'self', '.', 'value', '=', 'value', 'def', 'get', '_', 'value', '(', 'self', ')', ':', 'return'], ['value', 'def', 'get', '_', 'value', '(', 'self', ')', ':', 'return', 'self', '.', 'value', '5', '.', 'use', 'inline', 'comments', 'spa', '##ring'], ['self', '.', 'value', '5', '.', 'use', 'inline', 'comments', 'spa', '##ring', '##ly', ':', 'x', '=', 'x', '+', '1', '#', 'compensate', 'for'], ['##ly', ':', 'x', '=', 'x', '+', '1', '#', 'compensate', 'for', 'border', '6', '.', 'use', 'doc', '##st', '##ring', '##s', 'for', 'all'], ['border', '6', '.', 'use', 'doc', '##st', '##ring', '##s', 'for', 'all', 'public', 'modules', ',', 'functions', ',', 'classes', ',', 'and', 'methods', '.'], ['public', 'modules', ',', 'functions', ',', 'classes', ',', 'and', 'methods', '.', 'remember', ',', 'code', 'is', 'read', 'much', 'more', 'often', 'than', 'it'], ['remember', ',', 'code', 'is', 'read', 'much', 'more', 'often', 'than', 'it', 'is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!'], ['is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!']]
#
# Recursive with Overlap:
# Number of chunks 20
# [['pep', '8', ':', 'style', 'guide', 'for', 'python', 'code', '.'], ['this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency'], ['its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points'], ['across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code'], [':', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and'], ['.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':'], ['1', '.', 'use', '4', 'spaces', 'per', 'ind', '##entation', 'level', '.'], ['2', '.', 'limit', 'all', 'lines', 'to', 'a', 'maximum', 'of', '79', 'characters', '.'], ['3', '.', 'imports', 'should', 'usually', 'be', 'on', 'separate', 'lines', ':'], ['import', 'os', 'import', 'sy', '##s'], ['4', '.', 'surround', 'top', '-', 'level', 'function', 'and', 'class', 'definitions', 'with', 'two', 'blank', 'lines', '.'], ['def', 'example', '_', 'function', '(', ')', ':', "'", "'", "'", 'this', 'is', 'a', 'doc', '##st', '##ring', '.', "'", "'", "'"], ['this', 'is', 'a', 'doc', '##st', '##ring', '.', "'", "'", "'", 'return', 'none'], ['class', 'example', '##class', ':', "'", "'", "'", 'this', 'is', 'a', 'class', 'doc', '##st', '##ring', '.', "'", "'", "'", 'def', '_'], ['class', 'doc', '##st', '##ring', '.', "'", "'", "'", 'def', '_', '_', 'in', '##it', '_', '_', '(', 'self', ',', 'value', ')', ':', 'self', '.', 'value', '=', 'value', 'def', 'get', '_', 'value', '(', 'self', ')', ':', 'return', 'self', '.', 'value'], ['5', '.', 'use', 'inline', 'comments', 'spa', '##ring', '##ly', ':'], ['x', '=', 'x', '+', '1', '#', 'compensate', 'for', 'border'], ['6', '.', 'use', 'doc', '##st', '##ring', '##s', 'for', 'all', 'public', 'modules', ',', 'functions', ',', 'classes', ',', 'and', 'methods', '.'], ['remember', ',', 'code', 'is', 'read', 'much', 'more', 'often', 'than', 'it', 'is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!'], ['is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!']]
#
# Recursive Python Splitter with Overlap:
# Number of chunks 25
# [['pep', '8', ':', 'style', 'guide', 'for', 'python', 'code', '.', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its'], ['pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across'], ['goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':'], ['the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':', 'this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.'], ['this', 'pep', 'describes', 'a', 'style', 'guide', 'for', 'python', 'code', '.', 'its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency'], ['its', 'goal', 'is', 'to', 'improve', 'code', 'read', '##ability', 'and', 'consistency', 'across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points'], ['across', 'the', 'python', 'community', '.', 'here', 'are', 'some', 'key', 'points', ':', '1', '.', 'use', '4', 'spaces', 'per', 'ind', '##entation', 'level'], [':', '1', '.', 'use', '4', 'spaces', 'per', 'ind', '##entation', 'level', '.', '2', '.', 'limit', 'all', 'lines', 'to', 'a', 'maximum', 'of'], ['.', '2', '.', 'limit', 'all', 'lines', 'to', 'a', 'maximum', 'of', '79', 'characters', '.', '3', '.', 'imports', 'should', 'usually', 'be', 'on'], ['79', 'characters', '.', '3', '.', 'imports', 'should', 'usually', 'be', 'on', 'separate', 'lines', ':', 'import', 'os', 'import', 'sy', '##s', '4', '.'], ['separate', 'lines', ':', 'import', 'os', 'import', 'sy', '##s', '4', '.', 'surround', 'top', '-', 'level', 'function', 'and', 'class', 'definitions', 'with', 'two'], ['surround', 'top', '-', 'level', 'function', 'and', 'class', 'definitions', 'with', 'two', 'blank', 'lines', '.', 'def', 'example', '_', 'function', '(', ')', ':'], ['blank', 'lines', '.', 'def', 'example', '_', 'function', '(', ')', ':', "'", "'", "'", 'this', 'is', 'a', 'doc', '##st', '##ring', '.'], ["'", "'", "'", 'this', 'is', 'a', 'doc', '##st', '##ring', '.', "'", "'", "'", 'return', 'none', 'class', 'example', '##class', ':', "'"], ["'", "'", "'", 'return', 'none', 'class', 'example', '##class', ':', "'", "'", "'", 'this', 'is', 'a', 'class', 'doc', '##st', '##ring', '.'], ["'", "'", 'this', 'is', 'a', 'class', 'doc', '##st', '##ring', '.', "'", "'", "'", 'def', '_', '_', 'in', '##it', '_', '_'], ["'", "'", "'", 'def', '_', '_', 'in', '##it', '_', '_', '(', 'self', ',', 'value', ')', ':', 'self', '.', 'value', '='], ['(', 'self', ',', 'value', ')', ':', 'self', '.', 'value', '=', 'value', 'def', 'get', '_', 'value', '(', 'self', ')', ':', 'return'], ['value', 'def', 'get', '_', 'value', '(', 'self', ')', ':', 'return', 'self', '.', 'value', '5', '.', 'use', 'inline', 'comments', 'spa', '##ring'], ['self', '.', 'value', '5', '.', 'use', 'inline', 'comments', 'spa', '##ring', '##ly', ':', 'x', '=', 'x', '+', '1', '#', 'compensate', 'for'], ['##ly', ':', 'x', '=', 'x', '+', '1', '#', 'compensate', 'for', 'border', '6', '.', 'use', 'doc', '##st', '##ring', '##s', 'for', 'all'], ['border', '6', '.', 'use', 'doc', '##st', '##ring', '##s', 'for', 'all', 'public', 'modules', ',', 'functions', ',', 'classes', ',', 'and', 'methods', '.'], ['public', 'modules', ',', 'functions', ',', 'classes', ',', 'and', 'methods', '.', 'remember', ',', 'code', 'is', 'read', 'much', 'more', 'often', 'than', 'it'], ['remember', ',', 'code', 'is', 'read', 'much', 'more', 'often', 'than', 'it', 'is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!'], ['is', 'written', '.', 'clarity', 'and', 'read', '##ability', 'are', 'paramount', '!']]

# %%
strategies = [
    ("Fixed Token without Overlap", fixed_token_without_overlap, False),
    ("Fixed Token with Overlap", fixed_token_with_overlap, True),
    ("Recursive with Overlap", recursive_with_overlap, True),
    ("Recursive Python Splitter with Overlap", recursive_python_splitter_with_overlap, True),
    ("Semantic Chunking", semantic_chunking, False)
]

# %%
# for strategy_name, strategy_func, uses_overlap in strategies:
#     print(f"\n{strategy_name}:")
#     if strategy_name == "Semantic Chunking":
#         chunks = strategy_func(text)
#     else:
#         chunks = strategy_func(text, chunk_size, overlap) if uses_overlap else strategy_func(text, chunk_size)

#     for i, chunk in enumerate(chunks):
#         if strategy_name == "Semantic Chunking":
#             print(f"Chunk {i + 1}: {chunk[:100]}...")  # Print first 100 characters of each chunk
#         else:
#             print(f"Chunk {i + 1}: {tokens_to_string(chunk)[:100]}...")  # Print first 100 characters of each chunk
#     print(f"Total chunks: {len(chunks)}")

# %%
for strategy_name, strategy_func, uses_overlap in strategies:
    print("\n" + "*" * 60)
    print(f"\n{strategy_name}:")
    if strategy_name == "Semantic Chunking":
        chunks = strategy_func(text)
    else:
        chunks = strategy_func(text, chunk_size, overlap) if uses_overlap else strategy_func(text, chunk_size)

    for i, chunk in enumerate(chunks):
        if strategy_name == "Semantic Chunking":
            print(f"Chunk {i + 1}:\n{chunk}\n")
        else:
            print(f"Chunk {i + 1}:\n{tokens_to_string(chunk)}\n")
    print(f"Total chunks: {len(chunks)}")

# PEP 8: Style Guide for Python Code

# This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:
# Out:
# ************************************************************
#
# Fixed Token without Overlap:
# Chunk 1:
# pep 8 : style guide for python code. this pep describes a style guide for python code. its
#
# Chunk 2:
# goal is to improve code readability and consistency across the python community. here are some key points :
#
# Chunk 3:
# this pep describes a style guide for python code. its goal is to improve code readability and consistency
#
# Chunk 4:
# across the python community. here are some key points : 1. use 4 spaces per indentation level
#
# Chunk 5:
# . 2. limit all lines to a maximum of 79 characters. 3. imports should usually be on
#
# Chunk 6:
# separate lines : import os import sys 4. surround top - level function and class definitions with two
#
# Chunk 7:
# blank lines. def example _ function ( ) : ' ' ' this is a docstring.
#
# Chunk 8:
# ' ' ' return none class exampleclass : ' ' ' this is a class docstring.
#
# Chunk 9:
# ' ' ' def _ _ init _ _ ( self, value ) : self. value =
#
# Chunk 10:
# value def get _ value ( self ) : return self. value 5. use inline comments sparing
#
# Chunk 11:
# ##ly : x = x + 1 # compensate for border 6. use docstrings for all
#
# Chunk 12:
# public modules, functions, classes, and methods. remember, code is read much more often than it
#
# Chunk 13:
# is written. clarity and readability are paramount!
#
# Total chunks: 13
#
# ************************************************************
#
# Fixed Token with Overlap:
# Chunk 1:
# pep 8 : style guide for python code. this pep describes a style guide for python code. its
#
# Chunk 2:
# pep describes a style guide for python code. its goal is to improve code readability and consistency across
#
# Chunk 3:
# goal is to improve code readability and consistency across the python community. here are some key points :
#
# Chunk 4:
# the python community. here are some key points : this pep describes a style guide for python code.
#
# Chunk 5:
# this pep describes a style guide for python code. its goal is to improve code readability and consistency
#
# Chunk 6:
# its goal is to improve code readability and consistency across the python community. here are some key points
#
# Chunk 7:
# across the python community. here are some key points : 1. use 4 spaces per indentation level
#
# Chunk 8:
# : 1. use 4 spaces per indentation level. 2. limit all lines to a maximum of
#
# Chunk 9:
# . 2. limit all lines to a maximum of 79 characters. 3. imports should usually be on
#
# Chunk 10:
# 79 characters. 3. imports should usually be on separate lines : import os import sys 4.
#
# Chunk 11:
# separate lines : import os import sys 4. surround top - level function and class definitions with two
#
# Chunk 12:
# surround top - level function and class definitions with two blank lines. def example _ function ( ) :
#
# Chunk 13:
# blank lines. def example _ function ( ) : ' ' ' this is a docstring.
#
# Chunk 14:
# ' ' ' this is a docstring. ' ' ' return none class exampleclass : '
#
# Chunk 15:
# ' ' ' return none class exampleclass : ' ' ' this is a class docstring.
#
# Chunk 16:
# ' ' this is a class docstring. ' ' ' def _ _ init _ _
#
# Chunk 17:
# ' ' ' def _ _ init _ _ ( self, value ) : self. value =
#
# Chunk 18:
# ( self, value ) : self. value = value def get _ value ( self ) : return
#
# Chunk 19:
# value def get _ value ( self ) : return self. value 5. use inline comments sparing
#
# Chunk 20:
# self. value 5. use inline comments sparingly : x = x + 1 # compensate for
#
# Chunk 21:
# ##ly : x = x + 1 # compensate for border 6. use docstrings for all
#
# Chunk 22:
# border 6. use docstrings for all public modules, functions, classes, and methods.
#
# Chunk 23:
# public modules, functions, classes, and methods. remember, code is read much more often than it
#
# Chunk 24:
# remember, code is read much more often than it is written. clarity and readability are paramount!
#
# Chunk 25:
# is written. clarity and readability are paramount!
#
# Total chunks: 25
#
# ************************************************************
#
# Recursive with Overlap:
# Chunk 1:
# pep 8 : style guide for python code.
#
# Chunk 2:
# this pep describes a style guide for python code. its goal is to improve code readability and consistency
#
# Chunk 3:
# its goal is to improve code readability and consistency across the python community. here are some key points
#
# Chunk 4:
# across the python community. here are some key points : this pep describes a style guide for python code
#
# Chunk 5:
# : this pep describes a style guide for python code. its goal is to improve code readability and
#
# Chunk 6:
# . its goal is to improve code readability and consistency across the python community. here are some key points :
#
# Chunk 7:
# 1. use 4 spaces per indentation level.
#
# Chunk 8:
# 2. limit all lines to a maximum of 79 characters.
#
# Chunk 9:
# 3. imports should usually be on separate lines :
#
# Chunk 10:
# import os import sys
#
# Chunk 11:
# 4. surround top - level function and class definitions with two blank lines.
#
# Chunk 12:
# def example _ function ( ) : ' ' ' this is a docstring. ' ' '
#
# Chunk 13:
# this is a docstring. ' ' ' return none
#
# Chunk 14:
# class exampleclass : ' ' ' this is a class docstring. ' ' ' def _
#
# Chunk 15:
# class docstring. ' ' ' def _ _ init _ _ ( self, value ) : self. value = value def get _ value ( self ) : return self. value
#
# Chunk 16:
# 5. use inline comments sparingly :
#
# Chunk 17:
# x = x + 1 # compensate for border
#
# Chunk 18:
# 6. use docstrings for all public modules, functions, classes, and methods.
#
# Chunk 19:
# remember, code is read much more often than it is written. clarity and readability are paramount!
#
# Chunk 20:
# is written. clarity and readability are paramount!
#
# Total chunks: 20
#
# ************************************************************
#
# Recursive Python Splitter with Overlap:
# Chunk 1:
# pep 8 : style guide for python code. this pep describes a style guide for python code. its
#
# Chunk 2:
# pep describes a style guide for python code. its goal is to improve code readability and consistency across
#
# Chunk 3:
# goal is to improve code readability and consistency across the python community. here are some key points :
#
# Chunk 4:
# the python community. here are some key points : this pep describes a style guide for python code.
#
# Chunk 5:
# this pep describes a style guide for python code. its goal is to improve code readability and consistency
#
# Chunk 6:
# its goal is to improve code readability and consistency across the python community. here are some key points
#
# Chunk 7:
# across the python community. here are some key points : 1. use 4 spaces per indentation level
#
# Chunk 8:
# : 1. use 4 spaces per indentation level. 2. limit all lines to a maximum of
#
# Chunk 9:
# . 2. limit all lines to a maximum of 79 characters. 3. imports should usually be on
#
# Chunk 10:
# 79 characters. 3. imports should usually be on separate lines : import os import sys 4.
#
# Chunk 11:
# separate lines : import os import sys 4. surround top - level function and class definitions with two
#
# Chunk 12:
# surround top - level function and class definitions with two blank lines. def example _ function ( ) :
#
# Chunk 13:
# blank lines. def example _ function ( ) : ' ' ' this is a docstring.
#
# Chunk 14:
# ' ' ' this is a docstring. ' ' ' return none class exampleclass : '
#
# Chunk 15:
# ' ' ' return none class exampleclass : ' ' ' this is a class docstring.
#
# Chunk 16:
# ' ' this is a class docstring. ' ' ' def _ _ init _ _
#
# Chunk 17:
# ' ' ' def _ _ init _ _ ( self, value ) : self. value =
#
# Chunk 18:
# ( self, value ) : self. value = value def get _ value ( self ) : return
#
# Chunk 19:
# value def get _ value ( self ) : return self. value 5. use inline comments sparing
#
# Chunk 20:
# self. value 5. use inline comments sparingly : x = x + 1 # compensate for
#
# Chunk 21:
# ##ly : x = x + 1 # compensate for border 6. use docstrings for all
#
# Chunk 22:
# border 6. use docstrings for all public modules, functions, classes, and methods.
#
# Chunk 23:
# public modules, functions, classes, and methods. remember, code is read much more often than it
#
# Chunk 24:
# remember, code is read much more often than it is written. clarity and readability are paramount!
#
# Chunk 25:
# is written. clarity and readability are paramount!
#
# Total chunks: 25
#
# ************************************************************
#
# Semantic Chunking:
# Chunk 1:
#
# PEP 8: Style Guide for Python Code.
#
# This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:
# This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:
#
# 1.
#
# Chunk 2:
# Use 4 spaces per indentation level.
#
# 2. Limit all lines to a maximum of 79 characters.
#
# 3. Imports should usually be on separate lines:
#
# import os
# import sys
#
# 4. Surround top-level function and class definitions with two blank lines.
#
# def example_function():
#     '''This is a docstring.'''
#     return None
#
# class ExampleClass:
#     '''This is a class docstring.'''
#
#     def __init__(self, value):
#         self.value = value
#
#     def get_value(self):
#         return self.value
#
# 5. Use inline comments sparingly:
#
# x = x + 1  # Compensate for border
#
# 6. Use docstrings for all public modules, functions, classes, and methods.
#
# Remember, code is read much more often than it is written.
#
# Chunk 3:
# Clarity and readability are paramount!
#
#
# Total chunks: 3

# %%
semantic_chunking_strategy = ("Semantic Chunking", semantic_chunking)

print(f"\n{semantic_chunking_strategy[0]}:")
chunks = semantic_chunking_strategy[1](text)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i + 1}:\n{chunk}\n")
print(f"Total chunks: {len(chunks)}")
# Out:
# Semantic Chunking:
# Chunk 1:
#
# PEP 8: Style Guide for Python Code.
#
# This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:
# This PEP describes a style guide for Python code. Its goal is to improve code readability and consistency across the Python community. Here are some key points:
#
# 1.
#
# Chunk 2:
# Use 4 spaces per indentation level.
#
# 2. Limit all lines to a maximum of 79 characters.
#
# 3. Imports should usually be on separate lines:
#
# import os
# import sys
#
# 4. Surround top-level function and class definitions with two blank lines.
#
# def example_function():
#     '''This is a docstring.'''
#     return None
#
# class ExampleClass:
#     '''This is a class docstring.'''
#
#     def __init__(self, value):
#         self.value = value
#
#     def get_value(self):
#         return self.value
#
# 5. Use inline comments sparingly:
#
# x = x + 1  # Compensate for border
#
# 6. Use docstrings for all public modules, functions, classes, and methods.
#
# Remember, code is read much more often than it is written.
#
# Chunk 3:
# Clarity and readability are paramount!
#
#
# Total chunks: 3
